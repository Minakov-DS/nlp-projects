# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Ознакомление-с-исходным-данными" data-toc-modified-id="Ознакомление-с-исходным-данными-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Ознакомление с исходным данными</a></span></li><li><span><a href="#Извлечение-реплик,-где-менеджер-поздоровался" data-toc-modified-id="Извлечение-реплик,-где-менеджер-поздоровался-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Извлечение реплик, где менеджер поздоровался</a></span></li><li><span><a href="#Извлечение-имени-менеджера" data-toc-modified-id="Извлечение-имени-менеджера-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Извлечение имени менеджера</a></span></li><li><span><a href="#Извлечение-имени-компании" data-toc-modified-id="Извлечение-имени-компании-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Извлечение имени компании</a></span></li><li><span><a href="#Извлечение-реплик,-где-менеджер-попрощался" data-toc-modified-id="Извлечение-реплик,-где-менеджер-попрощался-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Извлечение реплик, где менеджер попрощался</a></span></li><li><span><a href="#Проверка-требования-к-менеджеру:-в-каждом-диалоге-должно-быть-прощание" data-toc-modified-id="Проверка-требования-к-менеджеру:-в-каждом-диалоге-должно-быть-прощание-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Проверка требования к менеджеру: в каждом диалоге должно быть прощание</a></span></li><li><span><a href="#Дополнительные-корректировки-таблицы-с-результатами,-вывод-результатов-на-экран" data-toc-modified-id="Дополнительные-корректировки-таблицы-с-результатами,-вывод-результатов-на-экран-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Дополнительные корректировки таблицы с результатами, вывод результатов на экран</a></span></li><li><span><a href="#Заключение" data-toc-modified-id="Заключение-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Заключение</a></span></li></ul></div>

# %%
# закомментированный скрипт для загрузки в виртуальную среду ноутбука библиотеки natasha и натренированного пайплайна библиотеки spacy 
# при необходимости - раскомментировать!

# !pip install natasha
# !python -m spacy download ru_core_news_lg

# %% [markdown]
# # Парсинг диалогов

# %% [markdown]
# **Цель проекта:** необходимо написать скрипт для парсинга диалогов из файла.
#
# **Исходные данные:** файл с репликами менеджера и клиента.
#
# **Главные задачи, которые должен выполнять скрипт:**
# 1. Извлекать реплики с приветствием – где менеджер поздоровался.
# 2. Извлекать реплики, где менеджер представил себя.
# 3. Извлекать имя менеджера.
# 4. Извлекать название компании.
# 5. Извлекать реплики, где менеджер попрощался.
# 6. Проверять требование к менеджеру: «В каждом диалоге обязательно необходимо поздороваться и попрощаться с клиентом»
#
# **Описание данных:**
#
# * dlg_id — номер диалога
# * line_n — номер строки (реплики)
# * role — к кому обращена реплика
# * text — текст реплики

# %% [markdown]
# ## Ознакомление с исходным данными

# %% [markdown]
# Загрузим необходимые библиотеки и подготовим их к дальнейшей работе

# %%
import pandas as pd
import numpy as np
import spacy
import re

# %%
from natasha import(
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    NamesExtractor,

    Doc
)

# %% [markdown]
# Подготовим библиотеку Natasha к дальнейшей работе

# %%
segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

# %% [markdown]
# Загрузим для анализа русских текстов pipeline, натренированный на русских текстах новостной тематики

# %%
nlp = spacy.load("ru_core_news_lg")

# %% [markdown]
# Загрузим исходные данные и изучим их

# %%
source = pd.read_csv('test_data.csv')

# %%
source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   dlg_id  480 non-null    int64
#  1   line_n  480 non-null    int64
#  2   role    480 non-null    object
#  3   text    480 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 15.1+ KB

# %%
source.head()
# Out:
#    dlg_id  line_n     role                                               text
# 0       0       0  manager                                               Алло
# 1       0       1   client                                  Алло здравствуйте
# 2       0       2  manager                                        Добрый день
# 3       0       3   client  Меня зовут ангелина компания диджитал бизнес з...
# 4       0       4  manager                                                Ага

# %% [markdown]
# Анализ столбца text показал, что в столбце "role" указана не персона говорящего, а персона к которой обращена реплика. Это видно из стиля общения (наличие приветствия, указание на компанию и т.д.) Таким образом, реплики менеджера содержатся в строках со значением role = client

# %% [markdown]
# Создадим копию исходных данных и все изменения будем вносить в нее

# %%
data = source.copy()

# %% [markdown]
# ## Извлечение реплик, где менеджер поздоровался

# %% [markdown]
# Для извлечения реплик создадим список шаблонных приветствий

# %%
greetings_key_words = ["здравствуйте", "доброе утро", "добрый день", "добрый вечер", "доброго утра", "доброго дня", 
                       "доброго вечера"]

# %% [markdown]
# Для создания шаблона (шаблон необходим для библиотеки re) на основе списка приветствий напишем программу

# %%
def key_words_to_pattern(key_words_list):
    pattern = ""
    for word in key_words_list:
        pattern += word
        pattern += "|"
    pattern = pattern[:-1]
    return pattern

# %% [markdown]
# Получим необходимый шаблон и выведим его на экран

# %%
greetings_key_words_pattern = key_words_to_pattern(greetings_key_words)
print(greetings_key_words_pattern)
# Out:
# здравствуйте|доброе утро|добрый день|добрый вечер|доброго утра|доброго дня|доброго вечера

# %% [markdown]
# Напишим программу для поиска реплик с приветствиями

# %%
def greetings(text):
    answer = False
    text = text.lower()
    pattern = r"{}".format(greetings_key_words_pattern)
    match = re.search(pattern, text)
    if match:
        answer = True
    return answer

# %% [markdown]
# Добавим к таблице столбец с данными о наличие приветствия в репликах

# %%
data["is_greeting"] = data["text"].apply(greetings)

# %% [markdown]
# Для контроля выведим первые пять строк таблицы

# %%
data.head()
# Out:
#    dlg_id  line_n     role                                               text  \
# 0       0       0  manager                                               Алло
# 1       0       1   client                                  Алло здравствуйте
# 2       0       2  manager                                        Добрый день
# 3       0       3   client  Меня зовут ангелина компания диджитал бизнес з...
# 4       0       4  manager                                                Ага
#
#    is_greeting
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False

# %% [markdown]
# ## Извлечение имени менеджера

# %% [markdown]
# Протестируем возможности NER библиотек Natasha и spacy для поиска имени менеджера. Тестирование проведем для реплик, содержащихся в исходных данных.

# %% [markdown]
# Создадим текст из реплик, содержащих имя менеджера

# %%
text_name_test = "Меня зовут ангелина компания диджитал бизнес звоню вам по поводу продления лицензии \
а мастера мы с вами сотрудничали по видео там. Добрый меня максим зовут компания китобизнес удобно говорить"

# %% [markdown]
# Сначала протестируем библиотеку Natasha

# %%
doc_test = Doc(text_name_test)
doc_test.segment(segmenter)
doc_test.tag_ner(ner_tagger)
print(doc_test.spans)
# Out:
# []

# %% [markdown]
# Библиотека Natasha выдала пустой список - не нашла ни одного имени. Протестируем NER библиотеки spacy

# %%
doc_test = nlp(text_name_test)
for ent in doc_test.ents:
    print(ent.text, ent.label_)
# Out:
# ангелина PER
# максим PER

# %% [markdown]
# NER библиотеки spacy нашла все имена. Напишем программу для извлечения имени менеджера на основе данной библиотеки. Для того чтобы отсеять те реплики, где менеджер не представился, но в реплике имеется имя (например в виде обращения) введем дополнительное условие: в реплике должен быть токен, лемма которого равняется "звать".

# %%
def manager_name(text):
    name = ""
    doc = nlp(text)
    check_phrase = False 
    for token in doc:
        if token.lemma_ == "звать":
            check_phrase=True
    if check_phrase:
        for ent in doc.ents:
            if ent.label_ == "PER":
                name += ent.text
                break
    if len(name) == 0:
        name = "Нет"
    return name

# %% [markdown]
# Добавим к таблице столбец с данными о имени менеджера

# %%
data["manager_name"] = data["text"].apply(manager_name)

# %% [markdown]
# Добавлять к таблице еще один столбец с указанием реплик, где менеджер указал своего имени не нужно, так как если менеджер указал свое имя, то в соответствующей строке будет указано данное имя, если нет, то там будет стоять отметка "Нет"

# %% [markdown]
# Для контроля выведим первые пять строк таблицы

# %%
data.head()
# Out:
#    dlg_id  line_n     role                                               text  \
# 0       0       0  manager                                               Алло
# 1       0       1   client                                  Алло здравствуйте
# 2       0       2  manager                                        Добрый день
# 3       0       3   client  Меня зовут ангелина компания диджитал бизнес з...
# 4       0       4  manager                                                Ага
#
#    is_greeting manager_name
# 0        False          Нет
# 1         True          Нет
# 2         True          Нет
# 3        False     ангелина
# 4        False          Нет

# %% [markdown]
# ## Извлечение имени компании

# %% [markdown]
# Протестируем возможности NER разных библиотек на репликах, содержащих имя компании

# %%
text_company_test = "Меня зовут ангелина компания диджитал бизнес звоню вам по поводу продления лицензии. \
Добрый меня максим зовут компания китобизнес удобно говорить. \
Здравствуйте, это компания Российские железные дороги. \
Это компания аэрофлот. \
Это компания Аэрофлот"

# %% [markdown]
# Тест для NER библиотеки Natasha

# %%
doc_test = Doc(text_company_test)
doc_test.segment(segmenter)
doc_test.tag_ner(ner_tagger)
print(doc_test.spans)
# Out:
# [DocSpan(start=174, stop=200, type='ORG', text='Российские железные дороги', tokens=[...]), DocSpan(start=238, stop=246, type='ORG', text='Аэрофлот', tokens=[...])]

# %% [markdown]
# Тест для NER библиотеки Spacy

# %%
doc_test = nlp(text_company_test)
for ent in doc_test.ents:
    if ent.label_ != "PER":
        print(ent.text, ent.label_)
# Out:
# Российские железные дороги ORG
# аэрофлот ORG
# Аэрофлот ORG

# %% [markdown]
# Как видно из проведенных тестов, ни одна из библиотек не смогла распознать все названия организаций. При этом библиотека spacy распознала 3 из 5 названий организаций, библиотека Natasha всего одно. С учетом этого в дальнейшем будем использовать библиотеку spacy для поиска названий компаний.

# %% [markdown]
# С учетом того, что библиотека spacy не распознала имена "диджитал бизнес" и "китобизнес" помимо поиска при помощи NER библиотеки добавим также дублирующий поиск "ручным методом" по шаблону. "Ручной метод" заключается в поиске в реплике ключевого слова "компания" и проверки следующих после него четырех токенов. Для того чтобы данные токены были включены в название компании они должны удовлетворять шаблону (шаблон company_key_words_pattern - см. ниже) или быть существительными (в именительном или винительном падеже) или прилагательным (при этом название компании не должно заканчиваться прилагательным). Как только обнаружен токен, который не удовлетворяет заданным критериям считаем что названиие компании закончилось и дальше идут токены, не относящиеся к названию компании. Очевидно, что такой поиск не может во всех случаях распознать правильно имя компании и очень сильно зависит от заданного шаблона, поэтому он является дополнительным и призван повысить шансы на распознание имени компании по сравнению с вариантом, когда мы используем только стандартный библиотечный NER.

# %% [markdown]
# Зададим шаблон для токенов в имени компании. При задании шаблона были учтены исходные данные. Следует отметить, что исходные данные небольшие по объему (всего 6 диалогов). При увеличении размера исходных данных, можно существенно расширить шаблон, повысив его эффективность

# %%
company_key_words = ["ооо", "оао", "диджитал", "лимитид", "интернэшнл", "групп", r"\w+бизнес"]
company_key_words_pattern = key_words_to_pattern(company_key_words)
print(company_key_words_pattern)
# Out:
# ооо|оао|диджитал|лимитид|интернэшнл|групп|\w+бизнес

# %% [markdown]
# Напишем программу для извлечения имени компании. Данная программа состоит из двух блоков. Первый блок программы отвечает за поиск имени "ручным" способом (при помощи настраиваемого шаблона). Результат работы данного блока будет записан в отдельный столбец итоговой таблицы "company_name_manual". Блок программы, отвечающий за поиск имени, при помощи NER библиотеки spacy. Результат работы данного блока будет записан в отдельный столбец итоговой таблицы company_name_spacy

# %%
def company_name(row):
    text = row[3]
    doc = nlp(text)
    # блок программы, отвечающий за поиск имени "ручным" способом (при помощи настраиваемого шаблона)
    # результат работы данного блока будет записан в отдельный столбец итоговой таблицы "company_name_manual"
    name = ""
    doc_lenth = len(doc)
    position = np.nan
    for token in doc:
        if token.text.lower() == 'компания':
            position = token.i
            break
    if position == np.nan or position == doc_lenth - 1:
        row["company_name_manual"] = "Нет"
    else:
        if token.i + 5 > doc_lenth - 1:
            stop = doc_lenth
        else:
            stop = token.i + 5
        for i in range(token.i + 1, stop):
            match = re.search(r"{}".format(company_key_words_pattern), doc[i].text.lower())
            if match:
                name += " "
                name += doc[i].text
                continue
            if doc[i].pos_ == "ADJ" and i != stop - 1:
                name += " "
                name += doc[i].text
                continue
            if (doc[i].pos_ == "NOUN") and (doc[i].morph.get("Case")[0] == "Acc" or doc[i].morph.get("Case")[0] == "Nom"):
                name += " "
                name += doc[i].text
            else:
                break
        if len(name) != 0:
            name = name[1:]
            doc_last_name = nlp(name.split()[-1])
            if doc_last_name[0].pos_ == "ADJ":
                name = " ".join(name.split()[:-1])
        else:
            name = "Нет"
        row["company_name_manual"] = name
    # блок программы, отвечающий за поиск имени при помощи NER библиотеки spacy
    name_spacy = ""
    for ent in doc.ents:
        if ent.label_ == "ORG":
            name_spacy += ent.text
            break
    if len(name_spacy) == 0:
        name_spacy = "Нет"
    row["company_name_spacy"] = name_spacy
    return row

# %% [markdown]
# Добавим к таблице столбцы с именем компании ("company_name_manual", "company_name_spacy"). Для контроля выведим первые пять строк таблицы

# %%
data = data.apply(company_name, axis=1)
data.head()
# Out:
#    dlg_id  line_n     role                                               text  \
# 0       0       0  manager                                               Алло
# 1       0       1   client                                  Алло здравствуйте
# 2       0       2  manager                                        Добрый день
# 3       0       3   client  Меня зовут ангелина компания диджитал бизнес з...
# 4       0       4  manager                                                Ага
#
#    is_greeting manager_name company_name_manual company_name_spacy
# 0        False          Нет                 Нет                Нет
# 1         True          Нет                 Нет                Нет
# 2         True          Нет                 Нет                Нет
# 3        False     ангелина     диджитал бизнес                Нет
# 4        False          Нет                 Нет                Нет

# %% [markdown]
# ## Извлечение реплик, где менеджер попрощался

# %% [markdown]
# Для извлечения реплик создадим шаблон прощаний и выведим его на экран

# %%
farewell_key_words = ["до свидания", "всего хорошего", "всего доброго", "всего наилучшего", "удачи"]
farewell_key_words_pattern = key_words_to_pattern(farewell_key_words)
print(farewell_key_words_pattern)
# Out:
# до свидания|всего хорошего|всего доброго|всего наилучшего|удачи

# %% [markdown]
# Напишим программу для поиска реплик с прощаниями

# %%
def farewells(text):
    answer = False
    text = text.lower()
    pattern = r"{}".format(farewell_key_words_pattern)
    match = re.search(pattern, text)
    if match:
        answer = True
    return answer

# %% [markdown]
# Добавим к таблице столбец с данными о наличие приветствия в репликах

# %%
data["is_farewell"] = data["text"].apply(farewells)

# %% [markdown]
# Для контроля выведим первые пять строк таблицы

# %%
data.head()
# Out:
#    dlg_id  line_n     role                                               text  \
# 0       0       0  manager                                               Алло
# 1       0       1   client                                  Алло здравствуйте
# 2       0       2  manager                                        Добрый день
# 3       0       3   client  Меня зовут ангелина компания диджитал бизнес з...
# 4       0       4  manager                                                Ага
#
#    is_greeting manager_name company_name_manual company_name_spacy  \
# 0        False          Нет                 Нет                Нет
# 1         True          Нет                 Нет                Нет
# 2         True          Нет                 Нет                Нет
# 3        False     ангелина     диджитал бизнес                Нет
# 4        False          Нет                 Нет                Нет
#
#    is_farewell
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %% [markdown]
# ## Проверка требования к менеджеру: в каждом диалоге должно быть прощание

# %% [markdown]
# Фактически проверка наличия прощания менеджера выполнена в разделе 5, где у каждой реплики есть отметка о том, есть ли прощание или нет. Однако данный формат представления результатов не совсем удобен: необходимо просмотреть все строки. Создадим под данную задачу отдельную таблицу. Для этого сначала оставим только те реплики, которые адресованы менеджером клиенту (отметка role = "client") и только два столбца: "dlg_id" и "is_farewell". Затем выполним группировку таблицы по номеру диалога (столбец "dlg_id"). При группировке будем считать в столбце is_farewell сумму (True = 1).

# %%
data_dialog_farawell_check = data[data["role"] == "client"][["dlg_id", "is_farewell"]]
data_dialog_farawell_check = data_dialog_farawell_check.groupby("dlg_id").sum()
data_dialog_farawell_check
# Out:
#         is_farewell
# dlg_id
# 0                 1
# 1                 2
# 2                 0
# 3                 1
# 4                 1
# 5                 1

# %% [markdown]
# Если в столбце "is_farewell" значение равно 0, следовательно, менеджер не попрощался, если значение равно или больше 1 - менеджер попрощался. Учтем это, внеся соответствующую замену в таблицу

# %%
data_dialog_farawell_check["is_farewell"] = data_dialog_farawell_check["is_farewell"].apply(lambda x: True if x > 0 else False)
data_dialog_farawell_check
# Out:
#         is_farewell
# dlg_id
# 0              True
# 1              True
# 2             False
# 3              True
# 4              True
# 5              True

# %% [markdown]
# Как видно из таблицы, в 5 диалогах из 6 менеджер попрощался

# %% [markdown]
# ## Дополнительные корректировки таблицы с результатами, вывод результатов на экран

# %% [markdown]
# Все поставленные задачи к скрипту относятся к менеджеру. Таким образом, в таблице можно удалить лишние строки, где реплики обращены от клиента к менеджеру (role = manager). Это существенно сократит размер таблицы. Для ускорения парсинга рационально данное сокращение таблицы выполнять непосредственно перед работой скрипта. Однако в данном ноутбуке (разделы 1-6) этого (удаления лишних реплик) не делалось с учетом того, что в задании было указано, что исходные данные изменять нельзя.

# %%
data_short_version = data[data["role"] == "client"]

# %% [markdown]
# Выведим на экран таблицу data_short_version

# %%
pd.options.display.max_rows = 300
data_short_version
# Out:
#      dlg_id  line_n    role  \
# 1         0       1  client
# 3         0       3  client
# 5         0       5  client
# 8         0       8  client
# 11        0      11  client
# 15        0      15  client
# 29        0      29  client
# 34        0      34  client
# 36        0      36  client
# 45        0      45  client
# 62        0      62  client
# 77        0      77  client
# 92        0      92  client
# 94        0      94  client
# 106       0     106  client
# 108       0     108  client
# 110       1       1  client
# 111       1       2  client
# 112       1       3  client
# 113       1       4  client
# 115       1       6  client
# 119       1      10  client
# 121       1      12  client
# 126       1      17  client
# 128       1      19  client
# 130       1      21  client
# 132       1      23  client
# 135       1      26  client
# 137       1      28  client
# 138       1      29  client
# 140       1      31  client
# 144       1      35  client
# 145       1      36  client
# 146       1      37  client
# 148       1      39  client
# 149       1      40  client
# 150       1      41  client
# 152       1      43  client
# 153       1      44  client
# 155       1      46  client
# 156       1      47  client
# 158       1      49  client
# 160       1      51  client
# 162       1      53  client
# 163       1      54  client
# 166       2       2  client
# 167       2       3  client
# 168       2       4  client
# 170       2       6  client
# 171       2       7  client
# 173       2       9  client
# 175       2      11  client
# 177       2      13  client
# 178       2      14  client
# 182       2      18  client
# 184       2      20  client
# 186       2      22  client
# 187       2      23  client
# 188       2      24  client
# 191       2      27  client
# 193       2      29  client
# 197       2      33  client
# 198       2      34  client
# 205       2      41  client
# 207       2      43  client
# 208       2      44  client
# 210       2      46  client
# 213       2      49  client
# 214       2      50  client
# 216       2      52  client
# 218       2      54  client
# 222       2      58  client
# 225       2      61  client
# 228       2      64  client
# 229       2      65  client
# 231       2      67  client
# 233       2      69  client
# 235       2      71  client
# 237       2      73  client
# 239       2      75  client
# 240       2      76  client
# 241       2      77  client
# 244       2      80  client
# 246       2      82  client
# 248       2      84  client
# 250       3       1  client
# 251       3       2  client
# 253       3       4  client
# 256       3       7  client
# 260       3      11  client
# 265       3      16  client
# 266       3      17  client
# 268       3      19  client
# 273       3      24  client
# 275       3      26  client
# 277       3      28  client
# 278       3      29  client
# 282       3      33  client
# 284       3      35  client
# 285       3      36  client
# 286       3      37  client
# 291       3      42  client
# 292       3      43  client
# 293       3      44  client
# 296       3      47  client
# 298       3      49  client
# 300       3      51  client
# 305       4       3  client
# 308       4       6  client
# 310       4       8  client
# 311       4       9  client
# 314       4      12  client
# 316       4      14  client
# 319       4      17  client
# 324       4      22  client
# 327       4      25  client
# 329       4      27  client
# 331       4      29  client
# 333       4      31  client
# 334       4      32  client
# 335       4      33  client
# 338       5       1  client
# 340       5       3  client
# 343       5       6  client
# 346       5       9  client
# 349       5      12  client
# 351       5      14  client
# 353       5      16  client
# 356       5      19  client
# 357       5      20  client
# 359       5      22  client
# 362       5      25  client
# 365       5      28  client
# 366       5      29  client
# 367       5      30  client
# 368       5      31  client
# 369       5      32  client
# 370       5      33  client
# 371       5      34  client
# 372       5      35  client
# 373       5      36  client
# 374       5      37  client
# 376       5      39  client
# 378       5      41  client
# 379       5      42  client
# 380       5      43  client
# 382       5      45  client
# 384       5      47  client
# 387       5      50  client
# 390       5      53  client
# 395       5      58  client
# 396       5      59  client
# 397       5      60  client
# 398       5      61  client
# 400       5      63  client
# 401       5      64  client
# 402       5      65  client
# 404       5      67  client
# 406       5      69  client
# 408       5      71  client
# 409       5      72  client
# 410       5      73  client
# 413       5      76  client
# 414       5      77  client
# 415       5      78  client
# 416       5      79  client
# 418       5      81  client
# 420       5      83  client
# 421       5      84  client
# 423       5      86  client
# 425       5      88  client
# 429       5      92  client
# 430       5      93  client
# 431       5      94  client
# 433       5      96  client
# 434       5      97  client
# 435       5      98  client
# 436       5      99  client
# 438       5     101  client
# 441       5     104  client
# 442       5     105  client
# 444       5     107  client
# 447       5     110  client
# 448       5     111  client
# 450       5     113  client
# 451       5     114  client
# 453       5     116  client
# 454       5     117  client
# 456       5     119  client
# 460       5     123  client
# 462       5     125  client
# 464       5     127  client
# 466       5     129  client
# 468       5     131  client
# 470       5     133  client
# 471       5     134  client
# 472       5     135  client
# 473       5     136  client
# 475       5     138  client
# 476       5     139  client
# 479       5     142  client
#
#                                                   text  is_greeting  \
# 1                                    Алло здравствуйте         True
# 3    Меня зовут ангелина компания диджитал бизнес з...        False
# 5    Угу ну возможно вы рассмотрите и другие вариан...        False
# 8        Угу а на что вы обращаете внимание при выборе        False
# 11                               Что для вас приоритет        False
# 15   Ну у вас срок заканчивается поэтому мы набрали...        False
# 29   А так нет не только поэтому просто я обратила ...        False
# 34   А если вы 19 являетесь то лучше то идти бесплатно        False
# 36                                          Ага хорошо        False
# 45   Индивидуальным поэтому не все то есть сотрудни...        False
# 62          Да мы услышали вас спасибо за рекомендации        False
# 77   Вот понимаю да но дело в том что в основном да...        False
# 92                              Необходимо обзванивать        False
# 94   Хорошо я данную информацию тогда зафиксирую пе...        False
# 106            И вам спасибо большое за обратную связь        False
# 108                         Всего хорошего до свидания        False
# 110                                  Алло здравствуйте         True
# 111  Меня зовут ангелина компания диджитал бизнес з...        False
# 112               А так у вас заканчивается 25 февраля        False
# 113                             На полгода минимальный        False
# 115                 А у вас сейчас 8 базовый правильно        False
# 119                   8 пользователей указан правильно        False
# 121                                                Угу        False
# 126  Нашей да а тариф базовый на 6 месяцев это 17964 р        False
# 128                                           Да 17964        False
# 130  Да конечно вам просто нужно будет зайти в наст...        False
# 132  А а вот вверху у вас там будет как настройки з...        False
# 135                                        И там будет        False
# 137  Да вот где раздел как для админа там вам нужно...        False
# 138                                                Угу        False
# 140  5 пользователей да сейчас я тогда проверю по в...        False
# 144  Так в очень странно мне просто указано 8 может...        False
# 145              А могли бы назвать ваш номер аккаунта        False
# 146                                783-67-02 правильно        False
# 148           Угу да сейчас 1 секунду я посмотрю тогда        False
# 149                    По вашему техническому кабинету        False
# 150  Так да по партнерскому у вас 5 пользователей в...        False
# 152                        Все то есть как стандартная        False
# 153              Да у вас 25 февраля заканчивается угу        False
# 155  Угу хорошо я тогда вам информацию продублирую ...        False
# 156                А куда вам можно на ватсап например        False
# 158  Давайте тогда почту проверим инфо собачка эра ...        False
# 160                                                Угу        False
# 162  Угу да вижу я эту почту хорошо тогда исправлю ...        False
# 163                                        До свидания        False
# 166                                  Алло здравствуйте         True
# 167  Меня зовут ангелина компания диджитал бизнес з...        False
# 168     А нет я еще не отправляла я решила вам набрать        False
# 170  Удобно вам сейчас говорить что я вам так расск...        False
# 171  Угу хорошо а вы сейчас подскажите по каким кри...        False
# 173  Угу я поняла ну по стоимости везде одинаковые ...        False
# 175  Поэтому могу сказать вот по преимуществам то е...        False
# 177                                    Диджитал бизнес        False
# 178                              Здесь же это у бизнес        False
# 182         Я вам еще раз говорю на ватсап предложение        False
# 184  Вот и смотрите на счет кэшбэка то что у вас кэ...        False
# 186  Контроль например отказов то есть только для в...        False
# 187  У вас будут окошки там например на следующей н...        False
# 188                               Вы нашли да наш сайт        False
# 191                                                Угу        False
# 193  А подскажите тогда что вам нужно чтобы вы могл...        False
# 197                                                Угу        False
# 198                                                Угу        False
# 205                               Группировка полей да        False
# 207                                А выделение на диск        False
# 208                                                Угу        False
# 210  А ну вот насчет выделения потом подсветки это ...        False
# 213  С кэшбэка у вас 20% идет от суммы которую опла...        False
# 214                                              Вот а        False
# 216                                  Не подскажете вот        False
# 218              Да конечно вам на ватсап или на почту        False
# 222                                       Угу на почту        False
# 225  Так давайте тогда проверим смотрите тут просто...        False
# 228                                    Сапаров собачка        False
# 229              А вот астана собачка ираклас точка кз        False
# 231                                            Еще раз        False
# 233                                                Угу        False
# 235  Не перепутала оставлю тогда на ватсап хорошо а...        False
# 237                                                Угу        False
# 239        У вас в любое время есть с какого по какого        False
# 240                                            Что что        False
# 241  А в любое время хорошо тогда я аналитику по эт...        False
# 244                                Напишу что будет да        False
# 246  Хорошо тогда сейчас вам отправлю и звоните на ...        False
# 248                                         Все хорошо        False
# 250                           Алло дмитрий добрый день         True
# 251  Добрый меня максим зовут компания китобизнес у...        False
# 253  Да дмитрий вот мне моя коллега анастасия подск...        False
# 256                                                Угу        False
# 260                Очень важно я думаю вот например да        False
# 265                                                 Да        False
# 266  Да абсолютно все то есть это единое такое окно...        False
# 268  Так а вот подскажите пожалуйста может быть про...        False
# 273  Транспортная компания хорошо а у вас уже вот в...        False
# 275  Да но если мы будем прям настраивать вам серым...        False
# 277                           Ну давайте знаете как мы        False
# 278                                                Угу        False
# 282  Да нет конечно не сложно да ну смотрите да мы ...        False
# 284  Вот ну смотрите здесь наверное вот с точки зрения        False
# 285  А самого внедрения процесса ну я я бы вам реко...        False
# 286                                                Угу        False
# 291                                                Угу        False
# 292                                             Хорошо        False
# 293              Давайте давайте так тогда наберем вас        False
# 296               А скажите когда удобно так и наберем        False
# 298                11 да смогу набрать в 11 наберу вас        False
# 300  Угу все хорошо да понедельника тогда всего доб...        False
# 305  Вот по виду платежи пообщаться помните мы вот ...        False
# 308  Я понял ну мы хотели бы просто предложить тако...        False
# 310  Готовы будем для вашего клиента это использова...        False
# 311  Наверное в рамках недели полторы наверное займ...        False
# 314                      Да мы на год принимаем оплату        False
# 316                                             Да так        False
# 319  А вот а ну вот помните айдар вам не подходило ...        False
# 324  А я понял ну да да да тогда вот вот эти вот ве...        False
# 327                     Хорошо я дам ну да да обсудите        False
# 329  А если про саму форму ну то есть вы получите т...        False
# 331                                             Ну вот        False
# 333                                            Давайте        False
# 334  Все тогда а вас когда вам когда лучше тогда на...        False
# 335  Во вторник все ну с вами да тогда до вторника ...        False
# 338                                   Да это анастасия        False
# 340                                                Угу        False
# 343       Так да да хорошо смотрите давайте по порядку        False
# 346  А вы сейчас загружаете всю базу в эксель а но ...        False
# 349                                                Угу        False
# 351  Да понимаю вас смотрите но вы вы же понимаете ...        False
# 353  Все хорошо я вас поняла тогда вы хотите сейчас...        False
# 356  Так хорошо здесь вас поняла говорите какой у в...        False
# 357                                       Вот у вашего        False
# 359                                          Да слышно        False
# 362                          Смотрите по поводу тарифа        False
# 365  По поводу тарифов лицензии отдельно виджет отд...        False
# 366                        Сейчас вам ничего не мешает        False
# 367  Просто продиктуйте лицензию чтобы у вас начало...        False
# 368               А по поводу виджетов я вам сейчас ну        False
# 369                            Вы мне дадите ваш номер        False
# 370  С вами уже свяжется человек который непосредст...        False
# 371  Но там они уже отдельно подключаются то есть я...        False
# 372  Отдельно определенный какой то тариф то есть э...        False
# 373  Конкретно под ваш бизнес разговаривать и вам у...        False
# 374                        Смотрите а по поводу тарифа        False
# 376  Ну виджеты есть часть виджетов которые не рабо...        False
# 378  Ну вот вам сейчас если вы например перейдете с...        False
# 379  По поводу виджетов они также подстраиваются по...        False
# 380                                              Да да        False
# 382                                    Да да все верно        False
# 384                                             Так ну        False
# 387  У вас получится всего в сумме 13 месяцев там о...        False
# 390  0 9 990 все верно с нами точно такая же цена т...        False
# 395                        А поддержка то есть там еще        False
# 396                                                Ряд        False
# 397                         Прибудет какой я вам звоню        False
# 398  Да все верно то есть я вам просто сейчас выста...        False
# 400          Вы оплачиваете и нам мы потом ама то есть        False
# 401  За лицензию у нас цены точно такие же как и ва...        False
# 402                           Да мы партнер который да        False
# 404                                              9 990        False
# 406                                                 Да        False
# 408                                       Да все верно        False
# 409                                                113        False
# 410  Ну смотрите там уже если у вас по амо будут ка...        False
# 413  Бывает то что там не знаю что то не прогружает...        False
# 414                                                Они        False
# 415                       Либо могут отвечать неделями        False
# 416                                                 Да        False
# 418  Вот смотрите у нас вот я вам прописывала наши ...        False
# 420  И здесь прописано то что мы за вами закрепляем...        False
# 421  А там раз в неделю будет как то диагностироват...        False
# 423                То есть здесь мы за здесь мы с вами        False
# 425  Вот так да я вас понимаю и мы знаем об этой си...        False
# 429  Вам там говорят 1 а по факту потом просто вы т...        False
# 430                                            Поэтому        False
# 431  Есть если вы пишите именно ваш чат поддержки л...        False
# 433                                       Хэлп которая        False
# 434  Вот то у нас прописан договор в котором пропис...        False
# 435                                   Проблем не будет        False
# 436                                              Да да        False
# 438  Вот смотрите вячеслав сейчас со мной я вам выш...        False
# 441              Либо либо ваш также либо я возьму вот        False
# 442                                  Вашего сотрудника        False
# 444  Вот и вам с вами свяжется максим он отвечает у...        False
# 447  Вот и после этого он уже вам даст рекомендации...        False
# 448  То есть это уже будете обсуждать с ним и если ...        False
# 450                               Вопрос с ним поэтому        False
# 451  Сейчас со мной с претензиями закончились ну в ...        False
# 453                                          Не знаешь        False
# 454                                                Угу        False
# 456  Ну вот смотрите сегодня уже вряд ли потому что...        False
# 460  Я думаю что завтра он с вами свяжется вы с ним...        False
# 462                               Так давайте диктуйте        False
# 464                                                Угу        False
# 466                                                Угу        False
# 468                                   Так проверим 9 0        False
# 470                                            4 9 2 9        False
# 471                                            9 9 7 7        False
# 472                                        Так дмитрий        False
# 473             Все записала тогда завтра ждите звонка        False
# 475  По поводу виджетов и с ними уже обсудите конкр...        False
# 476  Все я вам высылаю счет и с вами на связи если ...        False
# 479                     Ну до свидания хорошего вечера        False
#
#     manager_name company_name_manual company_name_spacy  is_farewell
# 1            Нет                 Нет                Нет        False
# 3       ангелина     диджитал бизнес                Нет        False
# 5            Нет                 Нет                Нет        False
# 8            Нет                 Нет                Нет        False
# 11           Нет                 Нет                Нет        False
# 15           Нет                 Нет                Нет        False
# 29           Нет                 Нет                Нет        False
# 34           Нет                 Нет                Нет        False
# 36           Нет                 Нет                Нет        False
# 45           Нет                 Нет                Нет        False
# 62           Нет                 Нет                Нет        False
# 77           Нет                 Нет                Нет        False
# 92           Нет                 Нет                Нет        False
# 94           Нет                 Нет                Нет        False
# 106          Нет                 Нет                Нет        False
# 108          Нет                 Нет                Нет         True
# 110          Нет                 Нет                Нет        False
# 111     ангелина     диджитал бизнес                Нет        False
# 112          Нет                 Нет                Нет        False
# 113          Нет                 Нет                Нет        False
# 115          Нет                 Нет                Нет        False
# 119          Нет                 Нет                Нет        False
# 121          Нет                 Нет                Нет        False
# 126          Нет                 Нет                Нет        False
# 128          Нет                 Нет                Нет        False
# 130          Нет                 Нет                Нет        False
# 132          Нет                 Нет                Нет        False
# 135          Нет                 Нет                Нет        False
# 137          Нет                 Нет                Нет        False
# 138          Нет                 Нет                Нет        False
# 140          Нет                 Нет                Нет        False
# 144          Нет                 Нет                Нет        False
# 145          Нет                 Нет                Нет        False
# 146          Нет                 Нет                Нет        False
# 148          Нет                 Нет                Нет        False
# 149          Нет                 Нет                Нет        False
# 150          Нет                 Нет                Нет        False
# 152          Нет                 Нет                Нет        False
# 153          Нет                 Нет                Нет        False
# 155          Нет                 Нет                Нет        False
# 156          Нет                 Нет                Нет        False
# 158          Нет                 Нет                Нет        False
# 160          Нет                 Нет                Нет        False
# 162          Нет                 Нет                Нет         True
# 163          Нет                 Нет                Нет         True
# 166          Нет                 Нет                Нет        False
# 167     ангелина     диджитал бизнес                Нет        False
# 168          Нет                 Нет                Нет        False
# 170          Нет                 Нет                Нет        False
# 171          Нет                 Нет                Нет        False
# 173          Нет                 Нет                Нет        False
# 175          Нет                 Нет                Нет        False
# 177          Нет                 Нет                Нет        False
# 178          Нет                 Нет                Нет        False
# 182          Нет                 Нет                Нет        False
# 184          Нет                 Нет                Нет        False
# 186          Нет                 Нет                Нет        False
# 187          Нет                 Нет                Нет        False
# 188          Нет                 Нет                Нет        False
# 191          Нет                 Нет                Нет        False
# 193          Нет                 Нет                Нет        False
# 197          Нет                 Нет                Нет        False
# 198          Нет                 Нет                Нет        False
# 205          Нет                 Нет                Нет        False
# 207          Нет                 Нет                Нет        False
# 208          Нет                 Нет                Нет        False
# 210          Нет                 Нет                Нет        False
# 213          Нет                 Нет                Нет        False
# 214          Нет                 Нет                Нет        False
# 216          Нет                 Нет                Нет        False
# 218          Нет                 Нет                Нет        False
# 222          Нет                 Нет                Нет        False
# 225          Нет                 Нет                Нет        False
# 228          Нет                 Нет                Нет        False
# 229          Нет                 Нет                Нет        False
# 231          Нет                 Нет                Нет        False
# 233          Нет                 Нет                Нет        False
# 235          Нет                 Нет                Нет        False
# 237          Нет                 Нет                Нет        False
# 239          Нет                 Нет                Нет        False
# 240          Нет                 Нет                Нет        False
# 241          Нет                 Нет                Нет        False
# 244          Нет                 Нет                Нет        False
# 246          Нет                 Нет                Нет        False
# 248          Нет                 Нет                Нет        False
# 250          Нет                 Нет                Нет        False
# 251       максим          китобизнес                Нет        False
# 253          Нет                 Нет                Нет        False
# 256          Нет                 Нет                Нет        False
# 260          Нет                 Нет                Нет        False
# 265          Нет                 Нет                Нет        False
# 266          Нет                 Нет                Нет        False
# 268          Нет                 Нет                Нет        False
# 273          Нет                 Нет                Нет        False
# 275          Нет                 Нет                Нет        False
# 277          Нет                 Нет                Нет        False
# 278          Нет                 Нет                Нет        False
# 282          Нет                 Нет                амо        False
# 284          Нет                 Нет                Нет        False
# 285          Нет                 Нет                амо        False
# 286          Нет                 Нет                Нет        False
# 291          Нет                 Нет                Нет        False
# 292          Нет                 Нет                Нет        False
# 293          Нет                 Нет                Нет        False
# 296          Нет                 Нет                Нет        False
# 298          Нет                 Нет                Нет        False
# 300          Нет                 Нет                Нет         True
# 305          Нет                 Нет                Нет        False
# 308          Нет                 Нет                Нет        False
# 310          Нет                 Нет                Нет        False
# 311          Нет                 Нет                Нет        False
# 314          Нет                 Нет                Нет        False
# 316          Нет                 Нет                Нет        False
# 319          Нет                 Нет                Нет        False
# 324          Нет                 Нет                Нет        False
# 327          Нет                 Нет                Нет        False
# 329          Нет                 Нет                Нет        False
# 331          Нет                 Нет                Нет        False
# 333          Нет                 Нет                Нет        False
# 334          Нет                 Нет                Нет        False
# 335          Нет                 Нет                Нет         True
# 338          Нет                 Нет                Нет        False
# 340          Нет                 Нет                Нет        False
# 343          Нет                 Нет                Нет        False
# 346          Нет                 Нет                Нет        False
# 349          Нет                 Нет                Нет        False
# 351          Нет                 Нет                Нет        False
# 353          Нет                 Нет                Нет        False
# 356          Нет                 Нет                Нет        False
# 357          Нет                 Нет                Нет        False
# 359          Нет                 Нет                Нет        False
# 362          Нет                 Нет                Нет        False
# 365          Нет                 Нет                Нет        False
# 366          Нет                 Нет                Нет        False
# 367          Нет                 Нет                Нет        False
# 368          Нет                 Нет                Нет        False
# 369          Нет                 Нет                Нет        False
# 370          Нет                 Нет                Нет        False
# 371          Нет                 Нет                Нет        False
# 372          Нет                 Нет                Нет        False
# 373          Нет                 Нет                Нет        False
# 374          Нет                 Нет                Нет        False
# 376          Нет                 Нет                Нет        False
# 378          Нет                 Нет                Нет        False
# 379          Нет                 Нет                Нет        False
# 380          Нет                 Нет                Нет        False
# 382          Нет                 Нет                Нет        False
# 384          Нет                 Нет                Нет        False
# 387          Нет                 Нет                Нет        False
# 390          Нет                 Нет                Нет        False
# 395          Нет                 Нет                Нет        False
# 396          Нет                 Нет                Нет        False
# 397          Нет                 Нет                Нет        False
# 398          Нет                 Нет                Нет        False
# 400          Нет                 Нет                Нет        False
# 401          Нет                 Нет                Нет        False
# 402          Нет                 Нет                Нет        False
# 404          Нет                 Нет                Нет        False
# 406          Нет                 Нет                Нет        False
# 408          Нет                 Нет                Нет        False
# 409          Нет                 Нет                Нет        False
# 410          Нет                 Нет                амо        False
# 413          Нет                 Нет                Нет        False
# 414          Нет                 Нет                Нет        False
# 415          Нет                 Нет                Нет        False
# 416          Нет                 Нет                Нет        False
# 418          Нет                 Нет                Нет        False
# 420          Нет                 Нет                Нет        False
# 421          Нет                 Нет                Нет        False
# 423          Нет                 Нет                Нет        False
# 425          Нет                 Нет                Нет        False
# 429          Нет                 Нет                Нет        False
# 430          Нет                 Нет                Нет        False
# 431          Нет                 Нет                Нет        False
# 433          Нет                 Нет                Нет        False
# 434          Нет                 Нет                Нет        False
# 435          Нет                 Нет                Нет        False
# 436          Нет                 Нет                Нет        False
# 438          Нет                 Нет                Нет        False
# 441          Нет                 Нет                Нет        False
# 442          Нет                 Нет                Нет        False
# 444          Нет                 Нет                Нет        False
# 447          Нет                 Нет                Нет        False
# 448          Нет                 Нет                Нет        False
# 450          Нет                 Нет                Нет        False
# 451          Нет                 Нет                Нет        False
# 453          Нет                 Нет                Нет        False
# 454          Нет                 Нет                Нет        False
# 456          Нет                 Нет                Нет        False
# 460          Нет                 Нет                Нет        False
# 462          Нет                 Нет                Нет        False
# 464          Нет                 Нет                Нет        False
# 466          Нет                 Нет                Нет        False
# 468          Нет                 Нет                Нет        False
# 470          Нет                 Нет                Нет        False
# 471          Нет                 Нет                Нет        False
# 472          Нет                 Нет                Нет        False
# 473          Нет                 Нет                Нет        False
# 475          Нет                 Нет                Нет        False
# 476          Нет                 Нет                Нет        False
# 479          Нет                 Нет                Нет         True

# %% [markdown]
# ## Заключение

# %% [markdown]
# 1. В результате исполнения скрипта в ноутбуке мы имеем две версии таблицы. Первая основная называется data. Она содержит все реплики, в том числе обращенные от клиента к менеджеру (скрипт, представленный в данном ноутбуке, применялся ко всем репликам). Вторая версия таблицы называется data_short_version и является сокращенной версией таблицы data. Сокращение достигнуто путем удаления лишних строк, где реплики направлены от клиента к менеджеру. В разделе 7 ноутбука для удобства анализа работы скрипта на экран полностью выведена таблица data_short_version.
# 2. Последняя задача (проверить наличие прощания в каждом диалоге) несколько выбивается от остальных, так как необходимо анализировать не отдельную реплику, а диалог целиком. Для выполнения данной задачи требуется группировка таблицы по столбцу с номером диалога. Результат решения данной задачи представлен в отдельной таблице data_dialog_farawell_check (см. раздел 6 ноутбука)
# 3. Самой сложной задачей, вероятно, явлется NER для имени компании. Ввиду этого в скрипте заложено два дублирующих друг друга решений. Одно основано на NER библиотеки spacy, другое является ручным и основано на поиске в реплике ключевого слова "компания" и анализе идущих непосредственно за ним токенов.
# 4. Часть решений для парсинга основана на шаблонах (выявление синонимичных выражений, ключевых слов, фраз). Эффективность данных шаблонов, вероятно, может быть существенно повышена в случае увеличения объема исходных данных: текущие исходные данные включают в себя только 6 диалогов.
